# %%
import pandas as pd

# Load the dataset
file_path = "Inpatient_payments.csv"  # update path if needed
df = pd.read_csv(file_path)

# Calculate missing values
missing_values = df.isnull().sum()
missing_values

# # Convert to DataFrame for better readability
# missing_df = pd.DataFrame({
#     'Column': missing_values.index,
#     'Missing_Count': missing_values.values,
#     'Missing_Percentage (%)': (missing_values.values / len(df)) * 100
# })

# # Sort by missing values (descending)
# missing_df = missing_df.sort_values(by='Missing_Count', ascending=False)

# # Display result
# print(missing_df)
# Out:
# Rndrng_Prvdr_CCN              0
# Rndrng_Prvdr_Org_Name         0
# Rndrng_Prvdr_City             0
# Rndrng_Prvdr_St               0
# Rndrng_Prvdr_State_FIPS       0
# Rndrng_Prvdr_Zip5             0
# Rndrng_Prvdr_State_Abrvtn     0
# Rndrng_Prvdr_RUCA            36
# Rndrng_Prvdr_RUCA_Desc       36
# DRG_Cd                        0
# DRG_Desc                      0
# Tot_Dschrgs                   0
# Avg_Submtd_Cvrd_Chrg          0
# Avg_Tot_Pymt_Amt              0
# Avg_Mdcr_Pymt_Amt             0
# dtype: int64
